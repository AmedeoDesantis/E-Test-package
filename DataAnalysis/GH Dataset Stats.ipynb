# %% [markdown]
# # Statistics of GitHub Projects
# - Spring Boot
# - Apache ShardingSphere
# - Apache Dolphinscheduler
# - Micrometer

# %%
# !mkdir -p "GitHubRepos"
# !cd "GitHubRepos" && git clone git@github.com:spring-projects/spring-boot.git && git checkout v3.1.12
# !cd "GitHubRepos" && git clone git@github.com:apache/shardingsphere.git && git checkout 5.5.0
# !cd "GitHubRepos" && git clone git@github.com:apache/dolphinscheduler.git && git checkout 3.2.1-release
# !cd "GitHubRepos" && git clone git@github.com:micrometer-metrics/micrometer.git && git checkout v1.11.12
# Out:
# Cloning into 'spring-boot'...
# remote: Enumerating objects: 989102, done.
# remote: Counting objects: 100% (1423/1423), done.
# remote: Compressing objects: 100% (305/305), done.
# remote: Total 989102 (delta 1173), reused 1158 (delta 1051), pack-reused 987679 (from 4)
# Receiving objects: 100% (989102/989102), 186.90 MiB | 9.77 MiB/s, done.
# Resolving deltas: 100% (445765/445765), done.
# Updating files: 100% (10324/10324), done.
# Cloning into 'shardingsphere'...
# remote: Enumerating objects: 1764210, done.
# remote: Counting objects: 100% (761/761), done.
# remote: Compressing objects: 100% (251/251), done.
# remote: Total 1764210 (delta 567), reused 510 (delta 510), pack-reused 1763449 (from 3)
# Receiving objects: 100% (1764210/1764210), 647.34 MiB | 8.81 MiB/s, done.
# Resolving deltas: 100% (695358/695358), done.
# Updating files: 100% (15636/15636), done.
# Cloning into 'dolphinscheduler'...
# remote: Enumerating objects: 256678, done.
# ...

# %%
# !bash describe_gh_stats.sh GitHubRepos/spring-boot
# Out:
# Total lines of code:              683988
# Number of classes:                  6901
# Number of test suites:              2261
# Total number of test cases:        13328
# Average test cases per suite:       5.89
# Average LOC per test suite:       135.82

# %%
# !bash describe_gh_stats.sh GitHubRepos/shardingsphere
# Out:
# Total lines of code:             1519076
# Number of classes:                  7635
# Number of test suites:              1382
# Total number of test cases:         5867
# Average test cases per suite:       4.25
# Average LOC per test suite:        92.28

# %%
# !bash describe_gh_stats.sh GitHubRepos/dolphinscheduler
# Out:
# Total lines of code:              257915
# Number of classes:                  2336
# Number of test suites:               469
# Total number of test cases:         1988
# Average test cases per suite:       4.24
# Average LOC per test suite:       143.54

# %%
# !bash describe_gh_stats.sh GitHubRepos/micrometer
# Out:
# Total lines of code:              166565
# Number of classes:                  1231
# Number of test suites:               385
# Total number of test cases:         1684
# Average test cases per suite:       4.37
# Average LOC per test suite:       191.01
