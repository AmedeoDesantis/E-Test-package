# %% [markdown]
# # RQ1: Impact of LLMs

# %% [markdown]
# - [Vanilla](#vanilla)
# - [Few-shot learning](#few-shot-learning)
# - [RAG](#rag)
# - [Baseline](#baseline)
# - [Fine-tuning](#fine-tuning)
# - [Effectiveness on Large Test Suite](#effectiveness-on-large-test-suite)

# %%
import os
import pandas as pd
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
)
from sklearn.dummy import DummyClassifier
import matplotlib.pyplot as plt
import numpy as np

# %%
EXPERIMENT_RESULTS_PATH = "../AutonomicTester/experiment_results"
LABELS = ["similar", "fixed", "buggy"]
FORMAL_LABELS = ["already-tested", "need-test", "error-prone"]
LARGE_TEST_SUITE_PATH = "plotdata/large_test_suite.csv"

# %%
# plt.rcParams.update({"text.usetex": True, "font.family": "Times New Roman"})

# %%
def compute_metrics(y_true: list, y_pred: list):
    precision = precision_score(
        y_true, y_pred, labels=LABELS, average=None, zero_division=0
    )
    recall = recall_score(y_true, y_pred, labels=LABELS, average=None, zero_division=0)
    f1 = f1_score(y_true, y_pred, labels=LABELS, average=None, zero_division=0)
    not_yet_tested_f1 = f1[1:].mean()
    avg_f1 = f1_score(y_true, y_pred, labels=LABELS, average="macro", zero_division=0)

    print(
        " | ".join(
            [f"{l}(P R F1)" for l in FORMAL_LABELS]
            + ["not-yet-tested F1", "Total Average F1"]
        )
    )
    print(
        " & ".join(
            [
                " & ".join([f"{precision[i]:.2f}", f"{recall[i]:.2f}", f"{f1[i]:.2f}"])
                for i in range(len(LABELS))
            ]
            + [f"{not_yet_tested_f1:.2f}", f"{avg_f1:.2f}"]
        )
    )
    f1_scores = {label: f1[i] for i, label in enumerate(FORMAL_LABELS)}
    f1_scores["not-yet-tested"] = not_yet_tested_f1
    f1_scores["total average"] = avg_f1
    metrics = {
        "precision": precision,
        "recall": recall,
        "f1": f1_scores,
    }
    return metrics


def summarize_metrics(llm_folder: str):
    """
    Summarize metrics about effectiveness for a specific LLM.

    Parameters
    ----------
    llm_folder: str
       folder name of experiments for a specific LLM
    """
    print("Summary Metrics of Experiment at", llm_folder)
    model_experiments_path = os.path.join(EXPERIMENT_RESULTS_PATH, llm_folder)
    classification_df_path = os.path.join(
        model_experiments_path, "scenario_classification.csv"
    )
    y_true = []
    y_pred = []
    if os.path.exists(classification_df_path):
        df_exp = pd.read_csv(classification_df_path)
        y_true = df_exp["target_scenario"].to_list()
        y_pred = df_exp["classified_scenario"].to_list()
    else:
        for experiment in os.listdir(model_experiments_path):
            experiment_path = os.path.join(model_experiments_path, experiment)
            # Skip not directories
            if not os.path.isdir(experiment_path):
                continue
            true_scenario = experiment.split("_")[-1]
            # Read statistics
            df_votes = pd.read_csv(os.path.join(experiment_path, "scenario_votes.csv"))
            df_votes["truth"] = true_scenario
            y_pred += df_votes["scenario"].to_list()
            y_true += df_votes["truth"].to_list()
    return compute_metrics(y_true, y_pred)

# %% [markdown]
# ## Vanilla

# %%
summarize_metrics("vanilla/Llama3 8B")
# Out:
# Summary Metrics of Experiment at vanilla/Llama3 8B
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.19 & 0.22 & 0.36 & 0.51 & 0.42 & 0.36 & 0.27 & 0.31 & 0.37 & 0.32
# {'precision': array([0.25647668, 0.35685484, 0.36084453]),
#  'recall': array([0.19001919, 0.51304348, 0.27325581]),
#  'f1': {'already-tested': np.float64(0.21830209481808158),
#   'need-test': np.float64(0.42092746730083236),
#   'error-prone': np.float64(0.3110008271298594),
#   'not-yet-tested': np.float64(0.36596414721534587),
#   'total average': 0.31674346308292445}}

# %%
summarize_metrics("vanilla/Llama3 70B")
# Out:
# Summary Metrics of Experiment at vanilla/Llama3 70B
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.18 & 0.29 & 0.22 & 0.34 & 0.28 & 0.31 & 0.28 & 0.19 & 0.23 & 0.27 & 0.25
# {'precision': array([0.18050066, 0.34177215, 0.28282828]),
#  'recall': array([0.29087049, 0.28222997, 0.19178082]),
#  'f1': {'already-tested': np.float64(0.22276422764227644),
#   'need-test': np.float64(0.30916030534351147),
#   'error-prone': np.float64(0.22857142857142856),
#   'not-yet-tested': np.float64(0.26886586695747),
#   'total average': 0.2534986538524055}}

# %%
summarize_metrics("vanilla/GPT3.5Turbo")
# Out:
# Summary Metrics of Experiment at vanilla/GPT3.5Turbo
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.10 & 0.15 & 0.35 & 0.64 & 0.46 & 0.36 & 0.23 & 0.28 & 0.37 & 0.30
# {'precision': array([0.2629108 , 0.35396226, 0.36093418]),
#  'recall': array([0.1023766 , 0.64158687, 0.23255814]),
#  'f1': {'already-tested': np.float64(0.14736842105263157),
#   'need-test': np.float64(0.45622568093385213),
#   'error-prone': np.float64(0.28286189683860236),
#   'not-yet-tested': np.float64(0.36954378888622724),
#   'total average': 0.2954853329416953}}

# %%
summarize_metrics("vanilla/GPT4Turbo")
# Out:
# Summary Metrics of Experiment at vanilla/GPT4Turbo
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.17 & 0.20 & 0.18 & 0.34 & 0.56 & 0.42 & 0.31 & 0.07 & 0.11 & 0.26 & 0.24
# {'precision': array([0.17138365, 0.33661741, 0.30967742]),
#  'recall': array([0.1996337 , 0.56087551, 0.06557377]),
#  'f1': {'already-tested': np.float64(0.1844331641285956),
#   'need-test': np.float64(0.42072857875833763),
#   'error-prone': np.float64(0.10822998872604284),
#   'not-yet-tested': np.float64(0.2644792837421902),
#   'total average': 0.23779724387099202}}

# %%
summarize_metrics("vanilla/GPT4o")
# Out:
# Summary Metrics of Experiment at vanilla/GPT4o
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.19 & 0.33 & 0.24 & 0.32 & 0.38 & 0.35 & 0.37 & 0.10 & 0.16 & 0.25 & 0.25
# {'precision': array([0.19251337, 0.31776765, 0.37113402]),
#  'recall': array([0.32967033, 0.38219178, 0.09849521]),
#  'f1': {'already-tested': np.float64(0.24307900067521945),
#   'need-test': np.float64(0.34701492537313433),
#   'error-prone': np.float64(0.15567567567567567),
#   'not-yet-tested': np.float64(0.251345300524405),
#   'total average': 0.24858986724134313}}

# %% [markdown]
# ## Few-shot learning

# %%
summarize_metrics("fewshot/GPT4Turbo 3shots")
# Out:
# Summary Metrics of Experiment at fewshot/GPT4Turbo 3shots
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.19 & 0.24 & 0.21 & 0.35 & 0.52 & 0.42 & 0.32 & 0.09 & 0.14 & 0.28 & 0.26
# {'precision': array([0.18777293, 0.34629295, 0.31627907]),
#  'recall': array([0.23626374, 0.52393981, 0.09302326]),
#  'f1': {'already-tested': np.float64(0.20924574209245742),
#   'need-test': np.float64(0.416984213391399),
#   'error-prone': np.float64(0.14376321353065538),
#   'not-yet-tested': np.float64(0.2803737134610272),
#   'total average': 0.2566643896715039}}

# %%
summarize_metrics("fewshot/GPT4Turbo 6shots")
# Out:
# Summary Metrics of Experiment at fewshot/GPT4Turbo 6shots
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.19 & 0.17 & 0.35 & 0.55 & 0.43 & 0.32 & 0.08 & 0.13 & 0.28 & 0.24
# {'precision': array([0.15178571, 0.34969325, 0.31770833]),
#  'recall': array([0.18715596, 0.54657534, 0.08356164]),
#  'f1': {'already-tested': np.float64(0.1676253081347576),
#   'need-test': np.float64(0.4265098877605559),
#   'error-prone': np.float64(0.13232104121475055),
#   'not-yet-tested': np.float64(0.2794154644876532),
#   'total average': 0.242152079036688}}

# %%
summarize_metrics("fewshot/GPT4Turbo 9shots")
# Out:
# Summary Metrics of Experiment at fewshot/GPT4Turbo 9shots
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.17 & 0.24 & 0.20 & 0.34 & 0.54 & 0.42 & 0.30 & 0.04 & 0.07 & 0.24 & 0.23
# {'precision': array([0.17232376, 0.34118674, 0.3       ]),
#  'recall': array([0.24264706, 0.53635117, 0.03703704]),
#  'f1': {'already-tested': np.float64(0.2015267175572519),
#   'need-test': np.float64(0.41706666666666664),
#   'error-prone': np.float64(0.06593406593406594),
#   'not-yet-tested': np.float64(0.24150036630036628),
#   'total average': 0.22817581671932816}}

# %% [markdown]
# ## RAG

# %%
summarize_metrics("rag/Llama3 8B")
# Out:
# Summary Metrics of Experiment at rag/Llama3 8B
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.23 & 0.28 & 0.26 & 0.43 & 0.51 & 0.47 & 0.53 & 0.37 & 0.44 & 0.45 & 0.39
# {'precision': array([0.23454545, 0.43174251, 0.53320683]),
#  'recall': array([0.28043478, 0.51251647, 0.37022398]),
#  'f1': {'already-tested': np.float64(0.25544554455445545),
#   'need-test': np.float64(0.4686746987951807),
#   'error-prone': np.float64(0.4370139968895801),
#   'not-yet-tested': np.float64(0.45284434784238037),
#   'total average': 0.3870447467464054}}

# %%
summarize_metrics("rag/Llama3 70B")
# Out:
# Summary Metrics of Experiment at rag/Llama3 70B
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.22 & 0.51 & 0.30 & 0.34 & 0.22 & 0.27 & 0.62 & 0.32 & 0.42 & 0.35 & 0.33
# {'precision': array([0.21626617, 0.33797217, 0.61832061]),
#  'recall': array([0.50869565, 0.22397892, 0.3201581 ]),
#  'f1': {'already-tested': np.float64(0.3035019455252918),
#   'need-test': np.float64(0.2694136291600634),
#   'error-prone': np.float64(0.421875),
#   'not-yet-tested': np.float64(0.3456443145800317),
#   'total average': 0.3315968582284517}}

# %%
summarize_metrics("rag/GPT3.5Turbo")
# Out:
# Summary Metrics of Experiment at rag/GPT3.5Turbo
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.19 & 0.08 & 0.11 & 0.42 & 0.71 & 0.53 & 0.60 & 0.40 & 0.48 & 0.50 & 0.37
# {'precision': array([0.19230769, 0.4191802 , 0.60039761]),
#  'recall': array([0.07608696, 0.7140975 , 0.39789196]),
#  'f1': {'already-tested': np.float64(0.10903426791277258),
#   'need-test': np.float64(0.5282651072124757),
#   'error-prone': np.float64(0.4786053882725832),
#   'not-yet-tested': np.float64(0.5034352477425295),
#   'total average': 0.3719682544659438}}

# %%
summarize_metrics("rag/GPT4Turbo")
# Out:
# Summary Metrics of Experiment at rag/GPT4Turbo
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.34 & 0.21 & 0.31 & 0.33 & 0.32 & 0.55 & 0.11 & 0.19 & 0.25 & 0.24
# {'precision': array([0.15347019, 0.30875   , 0.5483871 ]),
#  'recall': array([0.34130435, 0.32542819, 0.11198946]),
#  'f1': {'already-tested': np.float64(0.21173297370195548),
#   'need-test': np.float64(0.3168697883258499),
#   'error-prone': np.float64(0.18599562363238512),
#   'not-yet-tested': np.float64(0.2514327059791175),
#   'total average': 0.23819946188673013}}

# %%
summarize_metrics("rag/DeepseekR1 70B")
# Out:
# Summary Metrics of Experiment at rag/DeepseekR1 70B
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.18 & 0.29 & 0.22 & 0.29 & 0.24 & 0.26 & 0.52 & 0.45 & 0.48 & 0.37 & 0.32
# {'precision': array([0.17736486, 0.28921569, 0.51648352]),
#  'recall': array([0.28767123, 0.24016282, 0.44519621]),
#  'f1': {'already-tested': np.float64(0.219435736677116),
#   'need-test': np.float64(0.26241660489251295),
#   'error-prone': np.float64(0.47819767441860467),
#   'not-yet-tested': np.float64(0.37030713965555884),
#   'total average': 0.3200166719960779}}

# %% [markdown]
# ## Baseline
# Random classifier with equal probability for predicting each scenario.

# %%
dummy_clf = DummyClassifier(strategy="uniform")
X = list(range(1975))
y_true = ["buggy"] * 719 + ["fixed"] * 719 + ["similar"] * 537
dummy_clf.fit(X, y_true)
all_y_pred = []
all_y_true = []
for _ in range(10):
    y_pred = dummy_clf.predict(X)
    all_y_pred += y_pred.tolist()
    all_y_true += y_true
compute_metrics(all_y_true, all_y_pred)
# Out:
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.35 & 0.31 & 0.37 & 0.34 & 0.36 & 0.38 & 0.34 & 0.36 & 0.36 & 0.34
# {'precision': array([0.27872053, 0.37442922, 0.37601595]),
#  'recall': array([0.34562384, 0.34214186, 0.34102921]),
#  'f1': {'already-tested': np.float64(0.30858758001496384),
#   'need-test': np.float64(0.35755813953488375),
#   'error-prone': np.float64(0.3576690248705419),
#   'not-yet-tested': np.float64(0.35761358220271283),
#   'total average': 0.3412715814734632}}

# %% [markdown]
# ## Fine-tuning
# - E-Test
# - E-Test RAG

# %%
summarize_metrics("finetuning/FineTunedGPT3.5Turbo")
# Out:
# Summary Metrics of Experiment at finetuning/FineTunedGPT3.5Turbo
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.66 & 0.94 & 0.78 & 0.47 & 0.24 & 0.31 & 0.48 & 0.57 & 0.53 & 0.42 & 0.54
# {'precision': array([0.66129032, 0.47428571, 0.48387097]),
#  'recall': array([0.94433781, 0.23546099, 0.57446809]),
#  'f1': {'already-tested': np.float64(0.7778656126482213),
#   'need-test': np.float64(0.31469194312796206),
#   'error-prone': np.float64(0.5252918287937743),
#   'not-yet-tested': np.float64(0.4199918859608682),
#   'total average': 0.5392831281899859}}

# %%
summarize_metrics("rag/FineTunedGPT3.5Turbo")
# Out:
# Summary Metrics of Experiment at rag/FineTunedGPT3.5Turbo
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.47 & 0.41 & 0.44 & 0.51 & 0.61 & 0.56 & 0.52 & 0.46 & 0.49 & 0.52 & 0.50
# {'precision': array([0.46568627, 0.51495017, 0.52323838]),
#  'recall': array([0.41304348, 0.61264822, 0.45981555]),
#  'f1': {'already-tested': np.float64(0.4377880184331797),
#   'need-test': np.float64(0.5595667870036101),
#   'error-prone': np.float64(0.4894810659186536),
#   'not-yet-tested': np.float64(0.5245239264611319),
#   'total average': 0.49561195711848116}}

# %% [markdown]
# ### Temperature

# %%
def analyze_temperature_experiments() -> dict:
    temperature_experiments = {}
    target_path = os.path.join(EXPERIMENT_RESULTS_PATH, "temperature")
    for model_folder in os.listdir(target_path):
        model_path = os.path.join(target_path, model_folder)
        if not os.path.isdir(model_path):
            continue
        temperature_experiments[model_folder] = {}
        for repetition_folder in os.listdir(model_path):
            repetition_path = os.path.join(model_path, repetition_folder)
            if not os.path.isdir(repetition_path):
                continue
            temperature_experiments[model_folder][repetition_folder] = {}
            for temperature_folder in os.listdir(repetition_path):
                temperature_path = os.path.join(repetition_path, temperature_folder)
                if not os.path.isdir(temperature_path):
                    continue
                # read predictions and ground truths
                y_true = []
                y_pred = []
                if model_folder == "E-Test":
                    for experiment in os.listdir(temperature_path):
                        experiment_path = os.path.join(temperature_path, experiment)
                        # Skip not directories
                        if not os.path.isdir(experiment_path):
                            continue
                        df_exp = pd.read_csv(
                            os.path.join(experiment_path, "scenario_votes.csv")
                        )
                        y_true += df_exp["truth"].to_list()
                        y_pred += df_exp["scenario"].to_list()
                    if y_true == [] and y_pred == []:
                        df_exp = pd.read_csv(
                            os.path.join(temperature_path, "scenario_votes.csv")
                        )
                        y_true += df_exp["truth"].to_list()
                        y_pred += df_exp["scenario"].to_list()
                else:
                    df_exp = pd.read_csv(
                        os.path.join(temperature_path, "scenario_votes.csv")
                    )
                    y_true += df_exp["truth"].to_list()
                    y_pred += df_exp["scenario"].to_list()
                # compute metrics
                print(model_folder, repetition_folder, temperature_folder)
                temperature_experiments[model_folder][repetition_folder][
                    temperature_folder
                ] = compute_metrics(y_true, y_pred)
    return temperature_experiments

# %%
temperature_experiments = analyze_temperature_experiments()
# Out:
# Deepseek R1 70B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.31 & 0.28 & 0.36 & 0.20 & 0.26 & 0.38 & 0.50 & 0.43 & 0.34 & 0.32
# Deepseek R1 70B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.27 & 0.32 & 0.29 & 0.37 & 0.21 & 0.27 & 0.40 & 0.52 & 0.45 & 0.36 & 0.33
# Deepseek R1 70B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.24 & 0.27 & 0.25 & 0.31 & 0.16 & 0.22 & 0.39 & 0.54 & 0.46 & 0.34 & 0.31
# Deepseek R1 70B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.30 & 0.28 & 0.31 & 0.14 & 0.20 & 0.38 & 0.53 & 0.44 & 0.32 & 0.31
# Deepseek R1 70B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.64 & 0.37 & 0.34 & 0.11 & 0.16 & 0.38 & 0.24 & 0.30 & 0.23 & 0.28
# Deepseek R1 70B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.27 & 0.56 & 0.37 & 0.37 & 0.19 & 0.25 & 0.36 & 0.25 & 0.30 & 0.27 & 0.30
# Deepseek R1 70B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.67 & 0.36 & 0.36 & 0.08 & 0.13 & 0.32 & 0.16 & 0.21 & 0.17 & 0.24
# Deepseek R1 70B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.73 & 0.37 & 0.35 & 0.03 & 0.06 & 0.29 & 0.12 & 0.17 & 0.12 & 0.20
# Deepseek R1 70B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.75 & 0.38 & 0.33 & 0.04 & 0.07 & 0.32 & 0.13 & 0.19 & 0.13 & 0.21
# Deepseek R1 70B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.74 & 0.38 & 0.35 & 0.04 & 0.07 & 0.32 & 0.14 & 0.20 & 0.14 & 0.22
# Deepseek R1 70B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.74 & 0.37 & 0.37 & 0.04 & 0.07 & 0.31 & 0.13 & 0.18 & 0.13 & 0.21
# Deepseek R1 70B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.24 & 0.73 & 0.36 & 0.34 & 0.03 & 0.06 & 0.29 & 0.12 & 0.17 & 0.11 & 0.20
# E-Test repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.66 & 0.94 & 0.78 & 0.46 & 0.19 & 0.27 & 0.48 & 0.61 & 0.54 & 0.41 & 0.53
# E-Test repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.66 & 0.94 & 0.78 & 0.48 & 0.24 & 0.32 & 0.48 & 0.57 & 0.53 & 0.42 & 0.54
# E-Test repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.66 & 0.94 & 0.78 & 0.42 & 0.08 & 0.14 & 0.48 & 0.72 & 0.58 & 0.36 & 0.50
# E-Test repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.66 & 0.94 & 0.78 & 0.00 & 0.00 & 0.00 & 0.49 & 0.82 & 0.61 & 0.31 & 0.46
# E-Test repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.67 & 0.94 & 0.78 & 0.50 & 0.23 & 0.32 & 0.49 & 0.61 & 0.55 & 0.43 & 0.55
# E-Test repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.67 & 0.94 & 0.78 & 0.49 & 0.26 & 0.34 & 0.49 & 0.57 & 0.52 & 0.43 & 0.55
# E-Test repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.67 & 0.95 & 0.78 & 0.51 & 0.09 & 0.15 & 0.49 & 0.75 & 0.60 & 0.37 & 0.51
# E-Test repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.66 & 0.94 & 0.78 & 0.00 & 0.00 & 0.00 & 0.49 & 0.83 & 0.61 & 0.31 & 0.46
# E-Test repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.67 & 0.94 & 0.78 & 0.53 & 0.22 & 0.31 & 0.50 & 0.64 & 0.56 & 0.44 & 0.55
# E-Test repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.67 & 0.94 & 0.78 & 0.52 & 0.27 & 0.35 & 0.50 & 0.59 & 0.55 & 0.45 & 0.56
# E-Test repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.67 & 0.94 & 0.78 & 0.54 & 0.10 & 0.16 & 0.50 & 0.75 & 0.60 & 0.38 & 0.51
# E-Test repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.66 & 0.94 & 0.78 & 0.00 & 0.00 & 0.00 & 0.49 & 0.83 & 0.61 & 0.31 & 0.46
# Llama3 8B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.14 & 0.11 & 0.12 & 0.34 & 0.44 & 0.38 & 0.34 & 0.30 & 0.32 & 0.35 & 0.27
# Llama3 8B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.14 & 0.11 & 0.12 & 0.34 & 0.44 & 0.38 & 0.34 & 0.29 & 0.31 & 0.35 & 0.27
# Llama3 8B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.19 & 0.22 & 0.36 & 0.51 & 0.42 & 0.36 & 0.27 & 0.31 & 0.37 & 0.32
# Llama3 8B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.17 & 0.08 & 0.11 & 0.34 & 0.58 & 0.43 & 0.38 & 0.27 & 0.31 & 0.37 & 0.28
# Llama3 8B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.18 & 0.08 & 0.11 & 0.35 & 0.53 & 0.42 & 0.36 & 0.33 & 0.34 & 0.38 & 0.29
# Llama3 8B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.19 & 0.08 & 0.11 & 0.35 & 0.52 & 0.42 & 0.36 & 0.34 & 0.35 & 0.38 & 0.29
# Llama3 8B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.19 & 0.22 & 0.36 & 0.51 & 0.42 & 0.36 & 0.27 & 0.31 & 0.37 & 0.32
# Llama3 8B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.17 & 0.08 & 0.11 & 0.34 & 0.58 & 0.43 & 0.38 & 0.27 & 0.31 & 0.37 & 0.28
# Llama3 8B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.17 & 0.08 & 0.10 & 0.35 & 0.56 & 0.43 & 0.35 & 0.28 & 0.31 & 0.37 & 0.28
# Llama3 8B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.17 & 0.08 & 0.10 & 0.35 & 0.57 & 0.43 & 0.36 & 0.27 & 0.31 & 0.37 & 0.28
# Llama3 8B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.19 & 0.22 & 0.36 & 0.51 & 0.42 & 0.36 & 0.27 & 0.31 & 0.37 & 0.32
# Llama3 8B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.16 & 0.08 & 0.10 & 0.34 & 0.58 & 0.43 & 0.38 & 0.26 & 0.31 & 0.37 & 0.28
# Llama3 1B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.76 & 0.41 & 0.39 & 0.15 & 0.21 & 0.38 & 0.13 & 0.19 & 0.20 & 0.27
# Llama3 1B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.27 & 0.71 & 0.40 & 0.36 & 0.16 & 0.22 & 0.36 & 0.13 & 0.19 & 0.21 & 0.27
# Llama3 1B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.86 & 0.43 & 0.39 & 0.09 & 0.14 & 0.43 & 0.11 & 0.18 & 0.16 & 0.25
# Llama3 1B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.32 & 0.31 & 0.32 & 0.38 & 0.06 & 0.10 & 0.37 & 0.70 & 0.48 & 0.29 & 0.30
# Llama3 1B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.29 & 0.80 & 0.42 & 0.41 & 0.18 & 0.25 & 0.37 & 0.08 & 0.12 & 0.19 & 0.27
# Llama3 1B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.69 & 0.40 & 0.39 & 0.26 & 0.31 & 0.33 & 0.08 & 0.14 & 0.22 & 0.28
# Llama3 1B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.29 & 0.85 & 0.43 & 0.39 & 0.12 & 0.19 & 0.38 & 0.10 & 0.15 & 0.17 & 0.26
# Llama3 1B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.32 & 0.31 & 0.32 & 0.38 & 0.06 & 0.10 & 0.37 & 0.70 & 0.48 & 0.29 & 0.30
# Llama3 1B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.30 & 0.68 & 0.42 & 0.37 & 0.12 & 0.18 & 0.38 & 0.27 & 0.32 & 0.25 & 0.31
# Llama3 1B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.30 & 0.63 & 0.40 & 0.35 & 0.15 & 0.21 & 0.38 & 0.27 & 0.32 & 0.27 & 0.31
# Llama3 1B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.30 & 0.69 & 0.42 & 0.37 & 0.11 & 0.17 & 0.39 & 0.28 & 0.33 & 0.25 & 0.31
# Llama3 1B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.32 & 0.31 & 0.32 & 0.38 & 0.06 & 0.10 & 0.37 & 0.70 & 0.48 & 0.29 & 0.30
# Deepseek R1 7B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.26 & 0.26 & 0.37 & 0.54 & 0.44 & 0.36 & 0.21 & 0.27 & 0.35 & 0.32
# Deepseek R1 7B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.25 & 0.25 & 0.37 & 0.53 & 0.43 & 0.36 & 0.22 & 0.27 & 0.35 & 0.32
# Deepseek R1 7B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.23 & 0.23 & 0.23 & 0.35 & 0.30 & 0.32 & 0.35 & 0.40 & 0.37 & 0.35 & 0.31
# Deepseek R1 7B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.16 & 0.07 & 0.10 & 0.38 & 0.53 & 0.44 & 0.33 & 0.34 & 0.33 & 0.39 & 0.29
# Deepseek R1 7B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.20 & 0.06 & 0.09 & 0.37 & 0.48 & 0.42 & 0.36 & 0.44 & 0.39 & 0.41 & 0.30
# Deepseek R1 7B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.23 & 0.06 & 0.09 & 0.38 & 0.49 & 0.42 & 0.37 & 0.46 & 0.41 & 0.42 & 0.31
# Deepseek R1 7B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.07 & 0.09 & 0.38 & 0.52 & 0.44 & 0.36 & 0.37 & 0.37 & 0.40 & 0.30
# Deepseek R1 7B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.07 & 0.10 & 0.38 & 0.52 & 0.44 & 0.33 & 0.34 & 0.33 & 0.39 & 0.29
# Deepseek R1 7B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.17 & 0.05 & 0.08 & 0.36 & 0.45 & 0.40 & 0.36 & 0.45 & 0.40 & 0.40 & 0.29
# Deepseek R1 7B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.17 & 0.05 & 0.08 & 0.36 & 0.44 & 0.39 & 0.35 & 0.45 & 0.40 & 0.40 & 0.29
# Deepseek R1 7B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.16 & 0.06 & 0.09 & 0.36 & 0.48 & 0.41 & 0.37 & 0.42 & 0.39 & 0.40 & 0.30
# Deepseek R1 7B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.07 & 0.10 & 0.38 & 0.52 & 0.44 & 0.33 & 0.34 & 0.33 & 0.39 & 0.29
# Llama3 3B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.00 & 0.00 & 0.00 & 0.36 & 0.32 & 0.34 & 0.38 & 0.71 & 0.50 & 0.42 & 0.28
# Llama3 3B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 1.00 & 0.00 & 0.00 & 0.35 & 0.36 & 0.36 & 0.38 & 0.65 & 0.48 & 0.42 & 0.28
# Llama3 3B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.00 & 0.00 & 0.00 & 0.39 & 0.32 & 0.35 & 0.36 & 0.70 & 0.48 & 0.41 & 0.28
# Llama3 3B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.00 & 0.00 & 0.00 & 0.35 & 0.39 & 0.37 & 0.38 & 0.62 & 0.47 & 0.42 & 0.28
# Llama3 3B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.60 & 0.01 & 0.01 & 0.34 & 0.48 & 0.40 & 0.38 & 0.50 & 0.43 & 0.41 & 0.28
# Llama3 3B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.60 & 0.01 & 0.01 & 0.35 & 0.56 & 0.43 & 0.37 & 0.43 & 0.40 & 0.41 & 0.28
# Llama3 3B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.60 & 0.01 & 0.01 & 0.35 & 0.30 & 0.32 & 0.38 & 0.70 & 0.49 & 0.41 & 0.27
# Llama3 3B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.00 & 0.00 & 0.00 & 0.35 & 0.39 & 0.37 & 0.38 & 0.62 & 0.47 & 0.42 & 0.28
# Llama3 3B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.00 & 0.00 & 0.00 & 0.36 & 0.52 & 0.42 & 0.38 & 0.50 & 0.43 & 0.43 & 0.28
# Llama3 3B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.00 & 0.00 & 0.00 & 0.36 & 0.53 & 0.43 & 0.38 & 0.49 & 0.43 & 0.43 & 0.29
# Llama3 3B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.00 & 0.00 & 0.00 & 0.34 & 0.37 & 0.35 & 0.38 & 0.64 & 0.48 & 0.42 & 0.28
# Llama3 3B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.00 & 0.00 & 0.00 & 0.35 & 0.39 & 0.37 & 0.38 & 0.62 & 0.47 & 0.42 & 0.28
# Deepseek R1 1.5B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.29 & 0.48 & 0.36 & 0.35 & 0.18 & 0.24 & 0.38 & 0.38 & 0.38 & 0.31 & 0.33
# Deepseek R1 1.5B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.27 & 0.51 & 0.35 & 0.35 & 0.17 & 0.23 & 0.37 & 0.32 & 0.34 & 0.28 & 0.31
# Deepseek R1 1.5B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.27 & 0.46 & 0.34 & 0.33 & 0.14 & 0.20 & 0.38 & 0.38 & 0.38 & 0.29 & 0.31
# Deepseek R1 1.5B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.29 & 0.41 & 0.34 & 0.37 & 0.06 & 0.10 & 0.37 & 0.56 & 0.45 & 0.28 & 0.30
# Deepseek R1 1.5B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.44 & 0.33 & 0.34 & 0.23 & 0.28 & 0.34 & 0.27 & 0.30 & 0.29 & 0.30
# Deepseek R1 1.5B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.49 & 0.34 & 0.33 & 0.20 & 0.25 & 0.35 & 0.26 & 0.30 & 0.27 & 0.30
# Deepseek R1 1.5B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.44 & 0.32 & 0.36 & 0.19 & 0.25 & 0.37 & 0.35 & 0.36 & 0.30 & 0.31
# Deepseek R1 1.5B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.41 & 0.33 & 0.38 & 0.06 & 0.10 & 0.38 & 0.57 & 0.45 & 0.28 & 0.29
# Deepseek R1 1.5B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.56 & 0.37 & 0.36 & 0.17 & 0.23 & 0.39 & 0.30 & 0.34 & 0.29 & 0.31
# Deepseek R1 1.5B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.27 & 0.53 & 0.36 & 0.33 & 0.16 & 0.22 & 0.38 & 0.31 & 0.34 & 0.28 & 0.31
# Deepseek R1 1.5B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.29 & 0.57 & 0.38 & 0.36 & 0.23 & 0.28 & 0.41 & 0.25 & 0.31 & 0.30 & 0.32
# Deepseek R1 1.5B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.41 & 0.33 & 0.38 & 0.06 & 0.10 & 0.38 & 0.57 & 0.45 & 0.28 & 0.29
# Deepseek R1 32B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.18 & 0.22 & 0.39 & 0.44 & 0.41 & 0.39 & 0.45 & 0.42 & 0.42 & 0.35
# Deepseek R1 32B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.28 & 0.16 & 0.21 & 0.37 & 0.42 & 0.39 & 0.36 & 0.42 & 0.39 & 0.39 & 0.33
# Deepseek R1 32B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.15 & 0.19 & 0.34 & 0.38 & 0.36 & 0.39 & 0.47 & 0.43 & 0.39 & 0.33
# Deepseek R1 32B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.31 & 0.18 & 0.22 & 0.35 & 0.40 & 0.37 & 0.40 & 0.48 & 0.43 & 0.40 & 0.34
# Deepseek R1 32B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.37 & 0.30 & 0.39 & 0.34 & 0.37 & 0.31 & 0.23 & 0.26 & 0.32 & 0.31
# Deepseek R1 32B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.37 & 0.30 & 0.39 & 0.34 & 0.36 & 0.31 & 0.23 & 0.26 & 0.31 & 0.31
# Deepseek R1 32B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.25 & 0.37 & 0.30 & 0.39 & 0.35 & 0.37 & 0.31 & 0.23 & 0.26 & 0.32 & 0.31
# Deepseek R1 32B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.13 & 0.12 & 0.12 & 0.34 & 0.47 & 0.40 & 0.32 & 0.20 & 0.24 & 0.32 & 0.25
# Deepseek R1 32B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.13 & 0.13 & 0.13 & 0.34 & 0.48 & 0.40 & 0.32 & 0.19 & 0.24 & 0.32 & 0.25
# Deepseek R1 32B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.13 & 0.13 & 0.13 & 0.34 & 0.48 & 0.40 & 0.32 & 0.19 & 0.24 & 0.32 & 0.25
# Deepseek R1 32B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.13 & 0.13 & 0.13 & 0.34 & 0.48 & 0.40 & 0.32 & 0.19 & 0.24 & 0.32 & 0.25
# Deepseek R1 32B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.13 & 0.13 & 0.13 & 0.34 & 0.48 & 0.40 & 0.32 & 0.19 & 0.24 & 0.32 & 0.25
# Llama3 70B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.27 & 0.19 & 0.31 & 0.25 & 0.28 & 0.29 & 0.17 & 0.22 & 0.25 & 0.23
# Llama3 70B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.27 & 0.19 & 0.31 & 0.24 & 0.27 & 0.29 & 0.17 & 0.22 & 0.25 & 0.23
# Llama3 70B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.18 & 0.29 & 0.22 & 0.34 & 0.28 & 0.31 & 0.28 & 0.19 & 0.23 & 0.27 & 0.25
# Llama3 70B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.12 & 0.22 & 0.16 & 0.31 & 0.27 & 0.29 & 0.27 & 0.14 & 0.18 & 0.24 & 0.21
# Llama3 70B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.25 & 0.19 & 0.32 & 0.30 & 0.31 & 0.29 & 0.17 & 0.21 & 0.26 & 0.24
# Llama3 70B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.15 & 0.25 & 0.19 & 0.32 & 0.30 & 0.31 & 0.29 & 0.17 & 0.21 & 0.26 & 0.24
# Llama3 70B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.18 & 0.29 & 0.22 & 0.34 & 0.28 & 0.31 & 0.28 & 0.19 & 0.23 & 0.27 & 0.25
# Llama3 70B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.12 & 0.21 & 0.15 & 0.31 & 0.27 & 0.29 & 0.27 & 0.14 & 0.18 & 0.24 & 0.21
# Llama3 70B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.12 & 0.21 & 0.15 & 0.31 & 0.27 & 0.29 & 0.28 & 0.14 & 0.19 & 0.24 & 0.21
# Llama3 70B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.12 & 0.21 & 0.15 & 0.31 & 0.27 & 0.29 & 0.27 & 0.14 & 0.18 & 0.24 & 0.21
# Llama3 70B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.18 & 0.29 & 0.22 & 0.34 & 0.28 & 0.31 & 0.28 & 0.19 & 0.23 & 0.27 & 0.25
# Llama3 70B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.12 & 0.21 & 0.15 & 0.31 & 0.27 & 0.29 & 0.27 & 0.14 & 0.18 & 0.23 & 0.21
# Deepseek R1 14B repetition1 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.30 & 0.31 & 0.30 & 0.37 & 0.27 & 0.31 & 0.38 & 0.48 & 0.42 & 0.37 & 0.35
# Deepseek R1 14B repetition1 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.30 & 0.29 & 0.30 & 0.38 & 0.30 & 0.34 & 0.39 & 0.48 & 0.43 & 0.38 & 0.35
# Deepseek R1 14B repetition1 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.27 & 0.28 & 0.28 & 0.37 & 0.29 & 0.33 & 0.38 & 0.45 & 0.41 & 0.37 & 0.34
# Deepseek R1 14B repetition1 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.26 & 0.26 & 0.26 & 0.35 & 0.25 & 0.29 & 0.37 & 0.47 & 0.41 & 0.35 & 0.32
# Deepseek R1 14B repetition3 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.31 & 0.40 & 0.35 & 0.37 & 0.17 & 0.23 & 0.38 & 0.50 & 0.43 & 0.33 & 0.34
# Deepseek R1 14B repetition3 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.30 & 0.48 & 0.37 & 0.40 & 0.12 & 0.19 & 0.38 & 0.47 & 0.42 & 0.30 & 0.33
# Deepseek R1 14B repetition3 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.34 & 0.55 & 0.42 & 0.43 & 0.17 & 0.25 & 0.39 & 0.44 & 0.42 & 0.33 & 0.36
# Deepseek R1 14B repetition3 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.24 & 0.56 & 0.34 & 0.50 & 0.01 & 0.02 & 0.34 & 0.34 & 0.34 & 0.18 & 0.23
# Deepseek R1 14B repetition2 t1.5
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.32 & 0.67 & 0.43 & 0.47 & 0.07 & 0.12 & 0.41 & 0.43 & 0.42 & 0.27 & 0.32
# Deepseek R1 14B repetition2 t2
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.32 & 0.67 & 0.44 & 0.47 & 0.07 & 0.12 & 0.41 & 0.43 & 0.42 & 0.27 & 0.32
# Deepseek R1 14B repetition2 t0.75
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.31 & 0.70 & 0.43 & 0.43 & 0.17 & 0.25 & 0.38 & 0.25 & 0.31 & 0.28 & 0.33
# Deepseek R1 14B repetition2 t0
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.24 & 0.56 & 0.34 & 0.50 & 0.01 & 0.02 & 0.34 & 0.34 & 0.34 & 0.18 & 0.23

# %%
def print_tabular_metrics(temperature_experiments: dict, llm: str, temperature: float):
    repetition1 = temperature_experiments[llm]["repetition1"][f"t{temperature}"]
    repetition2 = temperature_experiments[llm]["repetition2"][f"t{temperature}"]
    repetition3 = temperature_experiments[llm]["repetition3"][f"t{temperature}"]
    precision = [
        np.mean(
            [
                repetition1["precision"][i],
                repetition2["precision"][i],
                repetition3["precision"][i],
            ]
        )
        for i in range(len(FORMAL_LABELS))
    ]
    print(f"average precision {np.mean(precision):.2f}")
    recall = [
        np.mean(
            [
                repetition1["recall"][i],
                repetition2["recall"][i],
                repetition3["recall"][i],
            ]
        )
        for i in range(len(FORMAL_LABELS))
    ]
    print(f"average recall {np.mean(recall):.2f}")
    f1 = {
        k: np.mean([repetition1["f1"][k], repetition2["f1"][k], repetition3["f1"][k]])
        for k in FORMAL_LABELS + ["not-yet-tested", "total average"]
    }
    # print(
    #     " | ".join(
    #         [f"{l}(P R F1)" for l in FORMAL_LABELS]
    #         + ["not-yet-tested F1", "Total Average F1"]
    #     )
    # )
    print(
        " & ".join(
            [rf"\review{{{llm}}}"]
            + [
                " & ".join(
                    [
                        rf"\review{{{precision[i]:.2f}}}",
                        rf"\review{{{recall[i]:.2f}}}",
                        rf"\review{{{f1[FORMAL_LABELS[i]]:.2f}}}",
                    ]
                )
                for i in range(len(FORMAL_LABELS))
            ]
            + [
                rf"\review{{{f1['not-yet-tested']:.2f}}}",
                rf"\review{{{f1['total average']:.2f}}}",
            ]
        )
    )

# %%
print_tabular_metrics(temperature_experiments, "Llama3 1B", 0.75)
print_tabular_metrics(temperature_experiments, "Llama3 3B", 0.75)
print_tabular_metrics(temperature_experiments, "Deepseek R1 1.5B", 0.75)
print_tabular_metrics(temperature_experiments, "Deepseek R1 7B", 0.75)
print_tabular_metrics(temperature_experiments, "Deepseek R1 14B", 0.75)
print_tabular_metrics(temperature_experiments, "Deepseek R1 32B", 0.75)
print_tabular_metrics(temperature_experiments, "Deepseek R1 70B", 0.75)
# Out:
# average precision 0.36
# average recall 0.36
# \review{Llama3 1B} & \review{0.29} & \review{0.80} & \review{0.43} & \review{0.39} & \review{0.11} & \review{0.17} & \review{0.40} & \review{0.16} & \review{0.22} & \review{0.19} & \review{0.27}
# average precision 0.31
# average recall 0.34
# \review{Llama3 3B} & \review{0.20} & \review{0.00} & \review{0.00} & \review{0.36} & \review{0.33} & \review{0.34} & \review{0.37} & \review{0.68} & \review{0.48} & \review{0.41} & \review{0.28}
# average precision 0.34
# average recall 0.34
# \review{Deepseek R1 1.5B} & \review{0.27} & \review{0.49} & \review{0.35} & \review{0.35} & \review{0.19} & \review{0.24} & \review{0.38} & \review{0.33} & \review{0.35} & \review{0.30} & \review{0.31}
# average precision 0.30
# average recall 0.32
# \review{Deepseek R1 7B} & \review{0.18} & \review{0.12} & \review{0.14} & \review{0.36} & \review{0.44} & \review{0.39} & \review{0.36} & \review{0.40} & \review{0.38} & \review{0.38} & \review{0.30}
# average precision 0.37
# average recall 0.37
# \review{Deepseek R1 14B} & \review{0.31} & \review{0.51} & \review{0.37} & \review{0.41} & \review{0.21} & \review{0.27} & \review{0.38} & \review{0.38} & \review{0.38} & \review{0.32} & \review{0.34}
# average precision 0.30
# average recall 0.31
# \review{Deepseek R1 32B} & \review{0.21} & \review{0.22} & \review{0.20} & \review{0.36} & \review{0.40} & \review{0.38} & \review{0.34} & \review{0.30} & \review{0.31} & \review{0.34} & \review{0.30}
# average precision 0.31
# average recall 0.31
# \review{Deepseek R1 70B} & \review{0.24} & \review{0.56} & \review{0.33} & \review{0.35} & \review{0.10} & \review{0.14} & \review{0.34} & \review{0.27} & \review{0.28} & \review{0.21} & \review{0.25}

# %%
print_tabular_metrics(temperature_experiments, "E-Test", 2)
# Out:
# average precision 0.55
# average recall 0.59
# \review{E-Test} & \review{0.67} & \review{0.94} & \review{0.78} & \review{0.49} & \review{0.26} & \review{0.34} & \review{0.49} & \review{0.58} & \review{0.53} & \review{0.43} & \review{0.55}

# %%
llm_map = {
    "Llama3": ["Llama3 1B", "Llama3 3B", "Llama3 8B", "Llama3 70B"],
    "Deepseek R1": [
        "Deepseek R1 1.5B",
        "Deepseek R1 7B",
        "Deepseek R1 14B",
        "Deepseek R1 32B",
        "Deepseek R1 70B",
    ],
}

# %%
def draw_avgf1_with_temperature(
    temperature_experiments: dict, f1_name: str, llm_family_name: str
):
    llm_family = llm_map[llm_family_name]
    ylabels = {
        "total average": "Avg. F1-score",
        "error-prone": r"F1-score of \textit{error-prone}",
        "need-test": r"F1-score of \textit{need-test}",
        "already-tested": r"F1-score of \textit{already-tested}",
        "not-yet-tested": r"F1-score of \textit{not-yet-tested}",
    }
    markers = ["o", "v", "s", "p", "*", "D"]
    marker_sizes = [7, 7, 7, 9, 10, 7]
    cmap = plt.get_cmap("tab10")
    colors = [cmap(i) for i in range(len(temperature_experiments))]
    fig, ax = plt.subplots(figsize=(8, 4))
    temperatures = [0, 0.75, 1.5, 2]  # temperatures of LLMs
    for index, model in enumerate(["E-Test"] + llm_family):
        repetitions = temperature_experiments[model]
        # aggregate f1 scores
        min_f1_scores = []
        avg_f1_scores = []
        max_f1_scores = []
        stds = []
        for temp in temperatures:
            f1_scores = [
                repetitions[rep_index][f"t{temp}"]["f1"][f1_name]
                for rep_index in ["repetition1", "repetition2", "repetition3"]
            ]
            stds.append(np.std(f1_scores))
            min_f1_scores.append(min(f1_scores))
            avg_f1_scores.append(np.mean(f1_scores))
            max_f1_scores.append(max(f1_scores))
        # plot
        ax.plot(
            temperatures,
            avg_f1_scores,
            marker=markers[index],
            markersize=marker_sizes[index],
            color=colors[index],
            label=model,
        )
        print(model)
        print("Avg. F1", ", ".join(["%.2f" % v for v in avg_f1_scores]))
        print("Std", ", ".join(["%.2f" % v for v in stds]))
        print(
            "Across temperatures",
            "%.2f" % np.mean(avg_f1_scores),
            "%.2f" % np.std(avg_f1_scores),
        )
        if model == "E-Test":
            ax.fill_between(
                temperatures,
                min_f1_scores,
                max_f1_scores,
                color=colors[index],
                alpha=0.3,
            )
        ax.set_ylim(0, 1)
        ax.set_xticks(temperatures)
        ax.tick_params(axis="both", labelsize=16)
        ax.set_xlabel("Temperature", fontsize=16)
        ax.set_ylabel(ylabels[f1_name], fontsize=16)
        ax.legend(ncol=2, fontsize=16)
        fig.savefig(
            f"images/inverse_scaling_by_temperature_{llm_family_name}_{f1_name}.pdf",
            bbox_inches="tight",
        )
        # fig.savefig(
        #     f"images/inverse_scaling_by_temperature_{llm_family_name}_{f1_name}.png",
        #     bbox_inches="tight",
        # )

# %%
draw_avgf1_with_temperature(temperature_experiments, "total average", "Deepseek R1")
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# E-Test
# Avg. F1 0.46, 0.51, 0.54, 0.55
# Std 0.00, 0.01, 0.01, 0.01
# Across temperatures 0.52 0.03
# Deepseek R1 1.5B
# Avg. F1 0.30, 0.31, 0.31, 0.30
# Std 0.00, 0.01, 0.01, 0.00
# Across temperatures 0.31 0.01
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# Deepseek R1 7B
# Avg. F1 0.29, 0.30, 0.31, 0.31
# Std 0.00, 0.01, 0.01, 0.01
# Across temperatures 0.30 0.01
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# Deepseek R1 14B
# Avg. F1 0.26, 0.34, 0.34, 0.33
# Std 0.04, 0.01, 0.01, 0.01
# Across temperatures 0.32 0.03
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# Deepseek R1 32B
# Avg. F1 0.28, 0.30, 0.30, 0.30
# Std 0.04, 0.03, 0.04, 0.03
# Across temperatures 0.30 0.01
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# Deepseek R1 70B
# Avg. F1 0.23, 0.25, 0.27, 0.28
# Std 0.05, 0.04, 0.05, 0.05
# Across temperatures 0.26 0.02
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.

# %%
draw_avgf1_with_temperature(temperature_experiments, "total average", "Llama3")
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# E-Test
# Avg. F1 0.46, 0.51, 0.54, 0.55
# Std 0.00, 0.01, 0.01, 0.01
# Across temperatures 0.52 0.03
# Llama3 1B
# Avg. F1 0.30, 0.27, 0.28, 0.29
# Std 0.00, 0.03, 0.02, 0.02
# Across temperatures 0.28 0.01
# Llama3 3B
# Avg. F1 0.28, 0.28, 0.28, 0.28
# Std 0.00, 0.00, 0.00, 0.00
# Across temperatures 0.28 0.00
# Llama3 8B
# Avg. F1 0.28, 0.32, 0.28, 0.28
# Std 0.00, 0.00, 0.01, 0.01
# Across temperatures 0.29 0.01
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# Llama3 70B
# Avg. F1 0.21, 0.25, 0.22, 0.22
# Std 0.00, 0.00, 0.01, 0.01
# Across temperatures 0.23 0.02

# %% [markdown]
# ## Effectiveness on Large Test Suite

# %%
TEST_SUITE_STATS_PATH = "plotdata/test_suite_stats.jsonl"
FILTERED_SCENARIOS_PATH = "plotdata/filtered_scenarios.csv"

# %%
df_filtered_scenarios = pd.read_csv(FILTERED_SCENARIOS_PATH)
df_test_suite_stats = pd.read_json(TEST_SUITE_STATS_PATH, lines=True)
df_test_suite_stats["bug"] = df_test_suite_stats["bug"].astype(int)

# %%
index_columns = ["project", "bug", "scenario_index"]
df_ts = df_filtered_scenarios.set_index(index_columns).join(
    df_test_suite_stats.set_index(index_columns), how="left"
)

# %%
df_ts
# Out:
#                                                                   buggy_class  \
# project bug scenario_index
# Chart   1   0               org.jfree.chart.renderer.category.AbstractCate...
#         2   1                         org.jfree.data.general.DatasetUtilities
#         3   0                                  org.jfree.data.time.TimeSeries
#         4   13                                    org.jfree.chart.plot.XYPlot
#         5   0                                      org.jfree.data.xy.XYSeries
# ...                                                                       ...
# Time    23  0                                      org.joda.time.DateTimeZone
#         24  6                       org.joda.time.format.DateTimeParserBucket
#         25  0                                      org.joda.time.DateTimeZone
#         26  21                           org.joda.time.chrono.ZonedChronology
#         27  0                     org.joda.time.format.PeriodFormatterBuilder
#
#                                                                  buggy_method  \
# project bug scenario_index
# Chart   1   0               org.jfree.chart.renderer.category.AbstractCate...
#         2   1               org.jfree.data.general.DatasetUtilities.iterat...
#         3   0               org.jfree.data.time.TimeSeries.createCopy(int,...
#         4   13              org.jfree.chart.plot.XYPlot.getDataRange(org.j...
#         5   0               org.jfree.data.xy.XYSeries.addOrUpdate(java.la...
# ...                                                                       ...
# Time    23  0               org.joda.time.DateTimeZone.getConvertedId(java...
#         24  6               org.joda.time.format.DateTimeParserBucket.comp...
#         25  0               org.joda.time.DateTimeZone.getOffsetFromLocal(...
#         26  21              org.joda.time.chrono.ZonedChronology.ZonedDate...
#         27  0               org.joda.time.format.PeriodFormatterBuilder.to...
#
#                                                               test_suite_name  \
# project bug scenario_index
# Chart   1   0               org.jfree.chart.renderer.category.junit.Abstra...
#         2   1               org.jfree.data.general.junit.DatasetUtilitiesT...
#         3   0                       org.jfree.data.time.junit.TimeSeriesTests
#         4   13                         org.jfree.chart.junit.XYAreaChartTests
#         5   0                           org.jfree.data.xy.junit.XYSeriesTests
# ...                                                                       ...
# Time    23  0                                  org.joda.time.TestDateTimeZone
#         24  6                      org.joda.time.format.TestDateTimeFormatter
#         25  0                           org.joda.time.TestDateTimeZoneCutover
#         26  21                          org.joda.time.TestDateTimeZoneCutover
#         27  0                 org.joda.time.format.TestPeriodFormatterBuilder
#
#                             test_case_count  num_chars  num_gpt_tokens  \
# project bug scenario_index
# Chart   1   0                             9      10287            2181
#         2   1                            52      36773            9669
#         3   0                            36      28126            7136
#         4   13                            0       1743             400
#         5   0                            20      11121            3185
# ...                                     ...        ...             ...
# Time    23  0                            41      33700            7128
#         24  6                            50      33424            9832
#         25  0                           111      55088           18392
#         26  21                          100      48136           16416
#         27  0                            53      37365            9254
#
#                             num_llama_tokens
# project bug scenario_index
# Chart   1   0                           2181
#         2   1                           9669
#         3   0                           7136
#         4   13                           400
#         5   0                           3185
# ...                                      ...
# Time    23  0                           7128
#         24  6                           9832
#         25  0                          18387
#         26  21                         16415
#         27  0                           9254
#
# [759 rows x 7 columns]

# %%
count_exceed_context_limit = len(df_ts[df_ts["num_gpt_tokens"] > 16385])
percentage_exceed_context_limit = 100 * count_exceed_context_limit / len(df_ts)
print(
    f"{percentage_exceed_context_limit:.2f}% scenarios include test suite size longer than 8K tokens, which exceeds the limit when building raw prompts"
)
# Out:
# 6.59% scenarios include test suite size longer than 8K tokens, which exceeds the limit when building raw prompts

# %%
df_rag = df_ts[df_ts["num_gpt_tokens"] > 16385]

# %%
df_rag.index.to_frame().to_csv("plotdata/large_test_suite.csv", index=False)

# %%
def compare_rag_improvement_over_large_test_suite(model: str):
    df_rag_exp = pd.read_csv(
        os.path.join(
            EXPERIMENT_RESULTS_PATH, "rag", model, "scenario_classification.csv"
        )
    )
    df_large_test_suite = pd.read_csv(LARGE_TEST_SUITE_PATH)[["project", "bug"]]
    # Read dataframe of experiment without RAG
    model_experiments_path = os.path.join(EXPERIMENT_RESULTS_PATH, "vanilla", model)
    exp_without_rag = []
    for experiment in os.listdir(model_experiments_path):
        experiment_path = os.path.join(
            model_experiments_path, experiment, "scenario_votes.csv"
        )
        true_scenario = experiment.split("_")[-1]
        df_exp = pd.read_csv(experiment_path)
        df_exp["target_scenario"] = true_scenario
        exp_without_rag.append(df_exp)
    df_exp_without_rag = pd.concat(exp_without_rag)
    df_exp_without_rag = df_exp_without_rag.rename(
        columns={"bug id": "bug", "scenario": "classified_scenario"}
    )[["project", "bug", "classified_scenario", "target_scenario"]]
    # Read dataframe of experiment with RAG
    df_exp_with_rag = df_rag_exp[
        ["project", "bug", "classified_scenario", "target_scenario"]
    ]
    # Filtered dataframe on large test suite
    df_exp_with_rag_large_ts = (
        df_large_test_suite.set_index(["project", "bug"])
        .join(df_exp_with_rag.set_index(["project", "bug"]))
        .reset_index()
    )
    df_exp_without_rag_large_ts = (
        df_large_test_suite.set_index(["project", "bug"])
        .join(df_exp_without_rag.set_index(["project", "bug"]))
        .reset_index()
    )
    print("With RAG")
    compute_metrics(
        df_exp_with_rag_large_ts["target_scenario"].tolist(),
        df_exp_with_rag_large_ts["classified_scenario"].tolist(),
    )
    print("\nWithout RAG")
    compute_metrics(
        df_exp_without_rag_large_ts["target_scenario"].tolist(),
        df_exp_without_rag_large_ts["classified_scenario"].tolist(),
    )

# %%
compare_rag_improvement_over_large_test_suite("Llama3 8B")
# Out:
# With RAG
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.35 & 0.52 & 0.42 & 0.55 & 0.52 & 0.54 & 0.64 & 0.50 & 0.56 & 0.55 & 0.50
#
# Without RAG
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.33 & 0.17 & 0.23 & 0.36 & 0.36 & 0.36 & 0.38 & 0.53 & 0.44 & 0.40 & 0.34

# %%
compare_rag_improvement_over_large_test_suite("Llama3 70B")
# Out:
# With RAG
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.23 & 0.55 & 0.32 & 0.33 & 0.16 & 0.22 & 0.62 & 0.42 & 0.50 & 0.36 & 0.35
#
# Without RAG
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.14 & 0.25 & 0.18 & 0.33 & 0.23 & 0.27 & 0.22 & 0.13 & 0.17 & 0.22 & 0.21

# %%
compare_rag_improvement_over_large_test_suite("GPT3.5Turbo")
# Out:
# With RAG
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.40 & 0.07 & 0.12 & 0.49 & 0.68 & 0.57 & 0.67 & 0.72 & 0.69 & 0.63 & 0.46
#
# Without RAG
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.18 & 0.06 & 0.09 & 0.31 & 0.61 & 0.41 & 0.36 & 0.20 & 0.25 & 0.33 & 0.25

# %%
compare_rag_improvement_over_large_test_suite("GPT4Turbo")
# Out:
# With RAG
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.18 & 0.55 & 0.27 & 0.38 & 0.24 & 0.29 & 0.67 & 0.12 & 0.20 & 0.25 & 0.26
#
# Without RAG
# already-tested(P R F1) | need-test(P R F1) | error-prone(P R F1) | not-yet-tested F1 | Total Average F1
# 0.03 & 0.03 & 0.03 & 0.31 & 0.57 & 0.40 & 0.00 & 0.00 & 0.00 & 0.20 & 0.14

# %%
def plot_bars_large_test_suite():
    fontsize_paper = 18
    # Settings for plots
    DARK_GREEN = "#1e8449"
    DARK_BLUE = "#2874a6"
    labels = ["Llama3 8B", "Llama3 70B", "GPT-3.5 Turbo", "GPT-4 Turbo"]
    models = ["Llama3 8B", "Llama3 70B", "GPT3.5Turbo", "GPT4Turbo"]
    values_without_rag = [0.34, 0.21, 0.25, 0.14]
    values_with_rag = [0.50, 0.35, 0.46, 0.26]
    width = 0.3
    fig, ax = plt.subplots(tight_layout=True)
    x = np.arange(len(labels))  # X locations for groups
    bars1 = ax.bar(
        x - width / 2,
        values_without_rag,
        width,
        label="prompt without RAG",
        color=DARK_GREEN,
    )
    bars2 = ax.bar(
        x + width / 2,
        values_with_rag,
        width,
        label="prompt with RAG",
        color=DARK_BLUE,
    )
    for i, v in enumerate(values_without_rag):
        if v != 0:
            ax.text(
                x[i] - width / 2,
                v,
                f"{v:.2f}",
                ha="center",
                va="bottom",
                fontsize=fontsize_paper,
            )
    for i, v in enumerate(values_with_rag):
        if v != 0:
            ax.text(
                x[i] + width / 2,
                v,
                f"{v:.2f}",
                ha="center",
                va="bottom",
                fontsize=fontsize_paper,
            )

    # Labels and title
    ax.set_ylabel("Total Avg. F1", fontsize=fontsize_paper)
    ax.set_xticks(x)  # Set ticks at group positions
    ax.set_xticklabels(labels, rotation=35, fontsize=fontsize_paper)  # Set tick labels
    ax.legend(fontsize=fontsize_paper)
    ax.tick_params(axis="y", labelsize=fontsize_paper)
    ax.set_ylim(top=0.8)
    fig.savefig("images/large_test_suite.pdf", bbox_inches="tight")

# %%
plot_bars_large_test_suite()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
